# %%
import pandas as pd
import numpy as npg
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')

#load the data and review
building_stats = pd.read_csv('/content/drive/My Drive/Colab Data/building_stats.csv')
building_stats.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     TaxParcel GrossAreasqft PropertyName       PropertyType PropertyUses  \
# 0   502640000         55220          NaN     APT 7-30 UNITS          NaN
# 1  2201177000         46686          NaN  CHURCH, SYNAGOGUE          NaN
# 2   402222010        123120          NaN            COLLEGE          NaN
# 3  2102478000         48655          NaN         CONDO MAIN          NaN
# 4  1103322000         20854          NaN         CONDO MAIN          NaN
#
#    YearBuilt  data_from
# 0        NaN       2021
# 1        NaN       2021
# 2        NaN       2021
# 3        NaN       2021
# 4        NaN       2021

# %%
building_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3609 entries, 0 to 3608
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TaxParcel      3609 non-null   object
#  1   GrossAreasqft  3575 non-null   object
#  2   PropertyName   2978 non-null   object
#  3   PropertyType   3606 non-null   object
#  4   PropertyUses   2966 non-null   object
#  5   YearBuilt      2978 non-null   float64
#  6   data_from      3609 non-null   int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 197.5+ KB

# %%
from google.colab import drive
drive.mount('/content/drive')

# load the data and review
energy_water_metrics = pd.read_csv('/content/drive/My Drive/Colab Data/reported_energy_and_water_metrics.csv')
energy_water_metrics.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    ReportYear                                            BERDOID  \
# 0        2023  105097, 105098, 105099, 105100, 105101, 105102...
# 1        2023                     105779, 105781, 105782, 105783
# 2        2023             106715, 107102, 107103, 107104, 107105
# 3        2023                             102580, 102581, 102582
# 4        2023                                     101822, 107009
#
#     TaxParcelID PropertyOwnerName                          BuildingAddress  \
# 0  1.102640e+09               NaN  461, 463, 467, 469, 493, 495 Arborway,
# 1           NaN               NaN                                      NaN
# 2           NaN               NaN                           550 Parker St.
# 3  1.806659e+09               NaN                                      NaN
# 4           NaN               NaN                           312 Border St.
#
#   BuildingAddressCity  BuildingAddressZipCode ParcelAddress ParcelAddressCity  \
# 0              boston                  2130.0           NaN               NaN
# 1                 NaN                     NaN           NaN               NaN
# 2              boston                  2120.0           NaN               NaN
# 3                 NaN                     NaN           NaN               NaN
# 4              boston                  2128.0           NaN               NaN
#
#    ParcelAddressZipCode  ...  BERDOReportStatus  \
# 0                   NaN  ...                NaN
# 1                   NaN  ...                NaN
# 2                   NaN  ...                NaN
# 3                   NaN  ...                NaN
# 4                   NaN  ...                NaN
#
#    EstimatedTotalGHGEmissionskgCO2e CommunityChoiceElectricityParticipation  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                               NaN                                     NaN
#
#   RenewableEnergyPurchasedthroughaPowerPurchaseAgreementPPA  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    RenewableEnergyCertificateRECPurchase  BackupGenerator  BatteryStorage  \
# 0                                    NaN              NaN             NaN
# 1                                    NaN              NaN             NaN
# 2                                    NaN              NaN             NaN
# 3                                    NaN              NaN             NaN
# 4                                    NaN              NaN             NaN
#
#    ElectricVehicleEVCharging  CoorespondingCampusID  \
# 0                        NaN              4331167.0
# 1                        NaN              6349839.0
# 2                        NaN             23642154.0
# 3                        NaN             25074587.0
# 4                        NaN              4028273.0
#
#                                                Notes
# 0  This is a campus comprised of multiple buildin...
# 1  This is a campus comprised of multiple buildin...
# 2  This is a campus comprised of multiple buildin...
# 3  This is a campus comprised of multiple buildin...
# 4  This is a campus comprised of multiple buildin...
#
# [5 rows x 42 columns]

# %%
energy_water_metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5981 entries, 0 to 5980
# Data columns (total 42 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   ReportYear                                                 5981 non-null   int64
#  1   BERDOID                                                    5980 non-null   object
#  2   TaxParcelID                                                5933 non-null   float64
#  3   PropertyOwnerName                                          5912 non-null   object
#  4   BuildingAddress                                            5956 non-null   object
#  5   BuildingAddressCity                                        5961 non-null   object
#  6   BuildingAddressZipCode                                     5957 non-null   float64
#  7   ParcelAddress                                              5897 non-null   object
#  8   ParcelAddressCity                                          5899 non-null   object
#  9   ParcelAddressZipCode                                       5899 non-null   float64
#  10  ReportedGrossFloorAreaSqFt                                 3042 non-null   float64
#  11  ReportedEnclosedParkingAreaSqFt                            195 non-null    float64
#  12  LargestPropertyType                                        2848 non-null   object
#  13  AllPropertyTypes                                           2961 non-null   object
#  14  SiteEUIEnergyUseIntensitykBtuft                            2690 non-null   float64
#  15  EnergyStarScore                                            1597 non-null   float64
#  16  TotalSiteEnergyUsagekBtu                                   2694 non-null   float64
#  17  NaturalGasUsagekBtu                                        2238 non-null   float64
#  18  ElectricityUsagekBtu                                       2685 non-null   float64
#  19  RenewableSystemElectricityUsageOnsitekBtu                  50 non-null     float64
#  20  DistrictHotWaterUsagekBtu                                  0 non-null      float64
#  21  DistrictChilledWaterUsagekBtu                              29 non-null     float64
#  22  DistrictSteamUsagekBtu                                     191 non-null    float64
#  23  FuelOil1UsagekBtu                                          9 non-null      float64
#  24  FuelOil2UsagekBtu                                          151 non-null    float64
#  25  FuelOil4UsagekBtu                                          0 non-null      float64
#  26  FuelOil5and6UsagekBtu                                      0 non-null      float64
#  27  PropaneUsagekBtu                                           1 non-null      float64
#  28  DieselUsagekBtu                                            7 non-null      float64
#  29  KeroseneUsagekBtu                                          0 non-null      float64
#  30  WaterUsageIntensityGallonsft                               2453 non-null   float64
#  31  ComplianceStatus                                           5911 non-null   object
#  32  BERDOReportStatus                                          5911 non-null   object
#  33  EstimatedTotalGHGEmissionskgCO2e                           2506 non-null   float64
#  34  CommunityChoiceElectricityParticipation                    3275 non-null   object
#  35  RenewableEnergyPurchasedthroughaPowerPurchaseAgreementPPA  3275 non-null   object
#  36  RenewableEnergyCertificateRECPurchase                      3275 non-null   object
#  37  BackupGenerator                                            3270 non-null   object
#  38  BatteryStorage                                             3270 non-null   object
#  39  ElectricVehicleEVCharging                                  3270 non-null   object
#  40  CoorespondingCampusID                                      540 non-null    float64
#  41  Notes                                                      1158 non-null   object
# dtypes: float64(24), int64(1), object(17)
# memory usage: 1.9+ MB

# %%
# Clean the TaxParcel column in building_stats by stripping whitespace and converting to string
building_stats['TaxParcel'] = building_stats['TaxParcel'].astype(str).str.strip()

# Convert TaxParcelID in energy_water_metrics to string, handling both float and string cases
def convert_to_string(value):
    try:
        # Try to convert float values to int, then to string to remove decimal points
        return str(int(float(value)))
    except (ValueError, TypeError):
        # If conversion fails, return an empty string for null or invalid values
        return ''

energy_water_metrics['TaxParcelID'] = energy_water_metrics['TaxParcelID'].apply(convert_to_string)

# Check for overlapping values between TaxParcel and TaxParcelID
overlapping_values = set(building_stats['TaxParcel']).intersection(set(energy_water_metrics['TaxParcelID']))
print(f'Number of overlapping values: {len(overlapping_values)}')

# Merge the datasets on the common column (TaxParcel and TaxParcelID) after cleaning
merged_data = pd.merge(building_stats, energy_water_metrics, left_on='TaxParcel', right_on='TaxParcelID', how='inner')

# Optionally save the merged dataset to a new CSV file
merged_data.to_csv('merged_building_energy_data.csv', index=False)
merged_data.info()
# Out:
# Number of overlapping values: 2185
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4879 entries, 0 to 4878
# Data columns (total 49 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   TaxParcel                                                  4879 non-null   object
#  1   GrossAreasqft                                              4857 non-null   object
#  2   PropertyName                                               4141 non-null   object
#  3   PropertyType                                               4877 non-null   object
#  4   PropertyUses                                               4141 non-null   object
#  5   YearBuilt                                                  4141 non-null   float64
#  6   data_from                                                  4879 non-null   int64
#  7   ReportYear                                                 4879 non-null   int64
#  8   BERDOID                                                    4879 non-null   object
#  9   TaxParcelID                                                4879 non-null   object
#  10  PropertyOwnerName                                          4862 non-null   object
#  11  BuildingAddress                                            4870 non-null   object
#  12  BuildingAddressCity                                        4872 non-null   object
#  13  BuildingAddressZipCode                                     4871 non-null   float64
#  14  ParcelAddress                                              4737 non-null   object
#  15  ParcelAddressCity                                          4740 non-null   object
#  16  ParcelAddressZipCode                                       4740 non-null   float64
#  17  ReportedGrossFloorAreaSqFt                                 3594 non-null   float64
#  18  ReportedEnclosedParkingAreaSqFt                            182 non-null    float64
#  19  LargestPropertyType                                        3445 non-null   object
#  20  AllPropertyTypes                                           3602 non-null   object
#  21  SiteEUIEnergyUseIntensitykBtuft                            3260 non-null   float64
#  22  EnergyStarScore                                            1799 non-null   float64
#  23  TotalSiteEnergyUsagekBtu                                   3268 non-null   float64
#  24  NaturalGasUsagekBtu                                        1938 non-null   float64
#  25  ElectricityUsagekBtu                                       3244 non-null   float64
#  26  RenewableSystemElectricityUsageOnsitekBtu                  174 non-null    float64
#  27  DistrictHotWaterUsagekBtu                                  0 non-null      float64
#  28  DistrictChilledWaterUsagekBtu                              181 non-null    float64
#  29  DistrictSteamUsagekBtu                                     1167 non-null   float64
#  30  FuelOil1UsagekBtu                                          4 non-null      float64
#  31  FuelOil2UsagekBtu                                          103 non-null    float64
#  32  FuelOil4UsagekBtu                                          0 non-null      float64
#  33  FuelOil5and6UsagekBtu                                      0 non-null      float64
#  34  PropaneUsagekBtu                                           2 non-null      float64
#  35  DieselUsagekBtu                                            11 non-null     float64
#  36  KeroseneUsagekBtu                                          0 non-null      float64
#  37  WaterUsageIntensityGallonsft                               2980 non-null   float64
#  38  ComplianceStatus                                           4861 non-null   object
#  39  BERDOReportStatus                                          4861 non-null   object
#  40  EstimatedTotalGHGEmissionskgCO2e                           3116 non-null   float64
#  41  CommunityChoiceElectricityParticipation                    3890 non-null   object
#  42  RenewableEnergyPurchasedthroughaPowerPurchaseAgreementPPA  3890 non-null   object
#  43  RenewableEnergyCertificateRECPurchase                      3890 non-null   object
#  44  BackupGenerator                                            3893 non-null   object
#  45  BatteryStorage                                             3893 non-null   object
#  46  ElectricVehicleEVCharging                                  3893 non-null   object
#  47  CoorespondingCampusID                                      735 non-null    float64
#  48  Notes                                                      1242 non-null   object
# dtypes: float64(24), int64(2), object(23)
# memory usage: 1.8+ MB

# %%
merged_data.head()
# Out:
#     TaxParcel GrossAreasqft PropertyName       PropertyType PropertyUses  \
# 0   502640000         55220          NaN     APT 7-30 UNITS          NaN
# 1  2201177000         46686          NaN  CHURCH, SYNAGOGUE          NaN
# 2   402222010        123120          NaN            COLLEGE          NaN
# 3   402222010        123120          NaN            COLLEGE          NaN
# 4   402222010        123120          NaN            COLLEGE          NaN
#
#    YearBuilt  data_from  ReportYear BERDOID TaxParcelID  ...  \
# 0        NaN       2021        2023  106400   502640000  ...
# 1        NaN       2021        2023  105392  2201177000  ...
# 2        NaN       2021        2023  104732   402222010  ...
# 3        NaN       2021        2023  104740   402222010  ...
# 4        NaN       2021        2023  104733   402222010  ...
#
#             BERDOReportStatus EstimatedTotalGHGEmissionskgCO2e  \
# 0             0 - Not Claimed                              NaN
# 1        1 - No Data Reported                              NaN
# 2  7 - Accepted by BERDO Team                              NaN
# 3  7 - Accepted by BERDO Team                              NaN
# 4  7 - Accepted by BERDO Team                              NaN
#
#   CommunityChoiceElectricityParticipation  \
# 0                                     NaN
# 1                                     NaN
# 2                                      No
# 3                                      No
# 4                                      No
#
#    RenewableEnergyPurchasedthroughaPowerPurchaseAgreementPPA  \
# 0                                                NaN
# 1                                                NaN
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   RenewableEnergyCertificateRECPurchase BackupGenerator  BatteryStorage  \
# 0                                   NaN             NaN             NaN
# 1                                   NaN             NaN             NaN
# 2                                    No             Yes              No
# 3                                    No             Yes              No
# 4                                    No             Yes              No
#
#    ElectricVehicleEVCharging  CoorespondingCampusID  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                         No              4021806.0
# 3                         No              4021806.0
# 4                         No              4021806.0
#
#                                                Notes
# 0                                                NaN
# 1                                                NaN
# 2  This building has been reported as part of a c...
# 3  This building has been reported as part of a c...
# 4  This building has been reported as part of a c...
#
# [5 rows x 49 columns]

# %%
# Drop rows with missing values in critical columns
merged_data = merged_data.dropna(subset=['TaxParcel', 'TaxParcelID', 'PropertyType'])

# Drop columns with more than 70% missing values
merged_data = merged_data.loc[:, merged_data.isnull().mean() < 0.7]

# Convert numerical columns that may be stored as strings to numeric types
numerical_columns = ['GrossAreasqft', 'ElectricityUsagekBtu', 'TotalSiteEnergyUsagekBtu']

for column in numerical_columns:
    # Convert to numeric, forcing errors to NaN if conversion fails
    merged_data[column] = pd.to_numeric(merged_data[column], errors='coerce')
    # Impute missing values with the median of the column
    merged_data[column].fillna(merged_data[column].median(), inplace=True)

# Impute categorical columns with the most common value (mode)
for column in ['PropertyType', 'BERDOReportStatus', 'CommunityChoiceElectricityParticipation']:
    merged_data[column].fillna(merged_data[column].mode()[0], inplace=True)

# Label missing categorical data as 'Unknown'
merged_data['RenewableEnergyCertificateRECPurchase'].fillna('Unknown', inplace=True)
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4877 entries, 0 to 4878
# Data columns (total 35 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   TaxParcel                                                  4877 non-null   object
#  1   GrossAreasqft                                              4877 non-null   float64
#  2   PropertyName                                               4141 non-null   object
#  3   PropertyType                                               4877 non-null   object
#  4   PropertyUses                                               4141 non-null   object
#  5   YearBuilt                                                  4141 non-null   float64
#  6   data_from                                                  4877 non-null   int64
#  7   ReportYear                                                 4877 non-null   int64
#  8   BERDOID                                                    4877 non-null   object
#  9   TaxParcelID                                                4877 non-null   object
#  10  PropertyOwnerName                                          4860 non-null   object
#  11  BuildingAddress                                            4868 non-null   object
#  12  BuildingAddressCity                                        4870 non-null   object
#  13  BuildingAddressZipCode                                     4869 non-null   float64
#  14  ParcelAddress                                              4735 non-null   object
#  15  ParcelAddressCity                                          4738 non-null   object
#  16  ParcelAddressZipCode                                       4738 non-null   float64
#  17  ReportedGrossFloorAreaSqFt                                 3593 non-null   float64
#  18  LargestPropertyType                                        3444 non-null   object
#  19  AllPropertyTypes                                           3601 non-null   object
#  20  SiteEUIEnergyUseIntensitykBtuft                            3259 non-null   float64
#  21  EnergyStarScore                                            1799 non-null   float64
#  22  TotalSiteEnergyUsagekBtu                                   4877 non-null   float64
#  23  NaturalGasUsagekBtu                                        1937 non-null   float64
#  24  ElectricityUsagekBtu                                       4877 non-null   float64
#  25  WaterUsageIntensityGallonsft                               2979 non-null   float64
#  26  ComplianceStatus                                           4859 non-null   object
#  27  BERDOReportStatus                                          4877 non-null   object
#  28  EstimatedTotalGHGEmissionskgCO2e                           3115 non-null   float64
#  29  CommunityChoiceElectricityParticipation                    4877 non-null   object
#  30  RenewableEnergyPurchasedthroughaPowerPurchaseAgreementPPA  3889 non-null   object
#  31  RenewableEnergyCertificateRECPurchase                      4877 non-null   object
#  32  BackupGenerator                                            3892 non-null   object
#  33  BatteryStorage                                             3892 non-null   object
#  34  ElectricVehicleEVCharging                                  3892 non-null   object
# dtypes: float64(12), int64(2), object(21)
# memory usage: 1.3+ MB

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

# Visualization 1: Missing Data Bar Chart Before Cleaning
plt.figure(figsize=(12, 6))
msno.bar(merged_data, color='skyblue', fontsize=12)
plt.title('Missing Data Visualization - After Cleaning', fontsize=14)
plt.show()

# Visualization 2: Comparison of Missing Values Before and After Cleaning

# Assuming you have the original dataset stored in `original_data`
original_data =  pd.read_csv('/content/drive/My Drive/Colab Data/reported_energy_and_water_metrics.csv')  # Load original data before cleaning
before_missing = original_data.isnull().sum()
after_missing = merged_data.isnull().sum()

missing_comparison = pd.DataFrame({
    'Before Cleaning': before_missing,
    'After Cleaning': after_missing,
})

# Plot the missing values
missing_comparison.plot(kind='bar', figsize=(18, 6))
plt.title('Comparison of Missing Values Before and After Cleaning')
plt.xlabel('Column Names')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=90)
# Create a dictionary to map long column names to their abbreviated versions
column_name_map = {
    'AllPropertyTypes': 'AllProps',
    'BERDOReportStatus': 'BERDOStatus',
    'BackupGenerator': 'BackGen',
    'BatteryStorage': 'BattStor',
    'BuildingAddress': 'BldgAddr',
    'BuildingAddressCity': 'BldgCity',
    'BuildingAddressZipCode': 'BldgZip',
    'CommunityChoiceElectricityParticipation': 'CommElec',
    'CoorespondingCampusID': 'CampusID',
    'DieselUsagekBtu': 'Diesel',
    'DistrictChilledWaterUsagekBtu': 'ChillWater',
    'DistrictHotWaterUsagekBtu': 'HotWater',
    'DistrictSteamUsagekBtu': 'Steam',
    'ElectricVehicleEVCharging': 'EVCharge',
    'ElectricityUsagekBtu': 'ElecUsage',
    'EnergyStarScore': 'EnergyScore',
    'EstimatedTotalGHGEmissionskgCO2e': 'GHGEmissions',
    'FuelOil1UsagekBtu': 'FOil1',
    'FuelOil2UsagekBtu': 'FOil2',
    'FuelOil4UsagekBtu': 'FOil4',
    'FuelOil5and6UsagekBtu': 'FOil5_6',
    'GrossAreasqft': 'GArea',
    'KeroseneUsagekBtu': 'Kerosene',
    'LargestPropertyType': 'LargestProp',
    'NaturalGasUsagekBtu': 'NatGas',
    'ParcelAddress': 'ParAddr',
    'ParcelAddressCity': 'ParCity',
    'ParcelAddressZipCode': 'ParZip',
    'PropaneUsagekBtu': 'Propane',
    'PropertyOwnerName': 'PropOwner',
    'PropertyType': 'PropType',
    'RenewableEnergyCertificateRECPurchase': 'RECPurch',
    'RenewableEnergyPurchasedthroughaPowerPurchaseAgreementPPA': 'PPA',
    'ReportedGrossFloorAreaSqFt': 'GrossFloor',
    'ReportedEnclosedParkingAreaSqFt': 'EnclosedParking',
    'ReportedOpenParkingAreaSqFt': 'OpenParking',
    'SiteEUIEnergyUseIntensitykBtuft': 'SiteEUI',
    'TaxParcel': 'TaxParcel',
    'TaxParcelID': 'TaxID',
    'TotalSiteEnergyUsagekBtu': 'TotalEnergy',
    'WaterUsageIntensityGallonsft': 'WaterUse',
    'YearBuilt': 'YrBuilt',
    'data_from': 'DataFrom',
    'ComplianceStatus': 'Compliance',
    'RenewableSystemElectricityUsageOnsitekBtu': 'RenewElec'
}

# Rename the columns in the missing_comparison DataFrame for the plot
missing_comparison.rename(index=column_name_map, inplace=True)

# Plot the missing values with shortened column names
missing_comparison.plot(kind='bar', figsize=(14, 8))
plt.title('Comparison of Missing Values Before and After Cleaning')
plt.xlabel('Column Names')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
